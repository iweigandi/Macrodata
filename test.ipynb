# %%
import pandas as pd

balances=pd.read_excel(r'C:\Users\weigandi\OneDrive - moodys.com\FIG Moodys Local - Shared with ML FIG team\Bancos Argentina\Contactos.xlsx')

# %%
balances
# Out:
#                                           Emisor                       Nombre  \
# 0                              Banco Supervielle               Bartesaghi Ana
# 1                                            NaN                Tewel Gustavo
# 2                              Banco Hipotecario          DIEZ MARTIN IGNACIO
# 3                                            NaN            BASCHKIER ELIEZER
# 4                                            NaN                FAES MILAGROS
# 5                                   Banco Comafi                Pochat, Pablo
# 6                                            NaN      Trevisan, Alexis Franco
# 7                        BNP Paribas (Argentina)               Adrian GABRIEL
# 8                                            NaN               Rodolfo ODISIO
# 9                                            NaN              Barbara CORDERO
# 10                                           NaN             Leonardo VERBNER
# ...
